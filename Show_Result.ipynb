# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarJCC/Professional-Internship-Project-Machine-Learning/blob/main/Show_Result.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
emocion = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/People_Data/Emocion.npy')
y_emocion = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/People_Data/y_Emocion.npy')

# %%
dic_y_emotion = {0:"Angry",
               1:"Disgust",
               2:"Fear",
               3:"Happy",
               4:"Neutral",
               5:"Sad",
               6:"Surprise"}

dic_emotion = {"ANS":"Angry",
               "DIS":"Disgust",
               "AFS":"Fear",
               "HAS":"Happy",
               "NES":"Neutral",
               "SAS":"Sad",
               "SUS":"Surprise"}

df_emotion = pd.DataFrame(dic_y_emotion.items(), columns=['Código', 'Emoción'])
df_emotion
# Out:
#    Código   Emoción
# 0       0     Angry
# 1       1   Disgust
# 2       2      Fear
# 3       3     Happy
# 4       4   Neutral
# 5       5       Sad
# 6       6  Surprise

# %%
emotion = []
for i in emocion:
  emotion.append(dic_emotion[str(i[-3:])])

# %%
people_z_train = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/People_Data/People_z_train.npy')

# %%
result_c = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/Complete_Data/Result.npy')
predict_pe1_c = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/Complete_Data/Predict_pe1.npy')
predict_pe2_c = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/Complete_Data/Predict_pe2.npy')

# %%
result_pe1 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe1_Data/Result.npy')
predict_pe1_pe1 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe1_Data/Predict_pe1.npy')
predict_pe2_pe1 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe1_Data/Predict_pe2.npy')

# %%
result_pe2 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe2_Data/Result.npy')
predict_pe1_pe2 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe2_Data/Predict_pe1.npy')
predict_pe2_pe2 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe2_Data/Predict_pe2.npy')

# %%
result_pe12 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe12_Data/Result.npy')
predict_pe1_pe12 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe12_Data/Predict_pe1.npy')
predict_pe2_pe12 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe12_Data/Predict_pe2.npy')

# %%
result = [0]*len(result_c)

for i in range(len(result_c)):
  result[i] = [result_c[i],result_pe1[i],result_pe2[i],result_pe12[i]]

e_t = ["Entrenamiento_Completo","Entrenamiento_pe1","Entrenamiento_pe2","Entrenamiento_pe12"]

result = np.asarray(result)

# %%
result_table = pd.DataFrame({'Entrenamiento':e_t, 'Training acc': result[0], 'Validation acc' : result[1], 'Training loss' : result[2], 'Validation loss' : result[3]})
result_table
# Out:
#             Entrenamiento  Training acc  Validation acc  Training loss  \
# 0  Entrenamiento_Completo      1.000000        0.714286       1.511212
# 1       Entrenamiento_pe1      0.993088        0.755102       1.310248
# 2       Entrenamiento_pe2      0.988479        0.795918       1.339411
# 3      Entrenamiento_pe12      0.995316        0.795918       1.322884
#
#    Validation loss
# 0         2.574861
# 1         2.088049
# 2         2.237170
# 3         2.063426

# %% [markdown]
# # Tablas de prediccion y clasificacion con Entrenamiento_Completo

# %% [markdown]
# ## Tabla de prediccion pe1

# %%
Angry_p_pe1_c, Disgust_p_pe1_c, Fear_p_pe1_c, Happy_p_pe1_c, Neutral_p_pe1_c, Sad_p_pe1_c, Surprise_p_pe1_c, pe1_c = [0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7

for i in range(len(predict_pe1_c)):
  Angry_p_pe1_c[i] = predict_pe1_c[i][0]
  Disgust_p_pe1_c[i] = predict_pe1_c[i][1]
  Fear_p_pe1_c[i] = predict_pe1_c[i][2]
  Happy_p_pe1_c[i] = predict_pe1_c[i][3]
  Neutral_p_pe1_c[i] = predict_pe1_c[i][4]
  Sad_p_pe1_c[i] = predict_pe1_c[i][5]
  Surprise_p_pe1_c[i] = predict_pe1_c[i][6]

for j in range(7):
  pe1_c[i] = dic_y_emotion[j]

predict_pe1_c_table = pd.DataFrame({'pe1_c':emotion, dic_y_emotion[0]:Angry_p_pe1_c, dic_y_emotion[1]:Disgust_p_pe1_c, dic_y_emotion[2]:Fear_p_pe1_c, dic_y_emotion[3]:Happy_p_pe1_c, dic_y_emotion[4]:Neutral_p_pe1_c, dic_y_emotion[5]:Sad_p_pe1_c, dic_y_emotion[6]:Surprise_p_pe1_c})
predict_pe1_c_table
# Out:
#       pe1_c         Angry   Disgust          Fear         Happy       Neutral  \
# 0   Disgust  3.696481e-10  1.000000  6.980819e-08  5.083553e-12  8.033923e-12
# 1      Fear  2.993370e-03  0.057809  8.870340e-01  6.752721e-04  1.477992e-03
# 2       Sad  8.122314e-05  0.006028  1.883476e-05  4.168301e-05  2.091703e-03
# 3   Neutral  9.699919e-07  0.006881  4.082919e-06  1.841780e-04  9.912709e-01
# 4  Surprise  6.787522e-06  0.000049  1.359480e-04  4.570183e-06  1.287394e-05
# 5     Angry  9.212227e-01  0.076432  1.205883e-03  1.454939e-04  4.991813e-04
# 6     Happy  1.684864e-08  0.009769  1.455611e-08  9.902294e-01  1.033233e-07
#
#             Sad      Surprise
# 0  5.513440e-09  1.477139e-10
# 1  4.396016e-02  6.050053e-03
# 2  9.917088e-01  3.005927e-05
# 3  1.611811e-03  4.684522e-05
# 4  1.216272e-05  9.997790e-01
# 5  2.636287e-04  2.307133e-04
# 6  7.410415e-07  2.047894e-07

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe1

# %%
Angry_cp_pe1_c, Disgust_cp_pe1_c, Fear_cp_pe1_c, Happy_cp_pe1_c, Neutral_cp_pe1_c, Sad_cp_pe1_c, Surprise_cp_pe1_c, pe1_c = [0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7
predict_y_pe1_c = np.zeros((7,7))
predict_y_emotion_pe1_c = [0]*7

for i in range(len(predict_pe1_c)):
  predict_y_pe1_c[i][np.argmax(predict_pe1_c[i])] = 1
  predict_y_emotion_pe1_c[i] = dic_y_emotion[np.argmax(predict_pe1_c[i])]

for i in range(len(predict_y_pe1_c)):
  Angry_cp_pe1_c[i] = int(predict_y_pe1_c[i][0])
  Disgust_cp_pe1_c[i] = int(predict_y_pe1_c[i][1])
  Fear_cp_pe1_c[i] = int(predict_y_pe1_c[i][2])
  Happy_cp_pe1_c[i] = int(predict_y_pe1_c[i][3])
  Neutral_cp_pe1_c[i] = int(predict_y_pe1_c[i][4])
  Sad_cp_pe1_c[i] = int(predict_y_pe1_c[i][5])
  Surprise_cp_pe1_c[i] = int(predict_y_pe1_c[i][6])

clasif_predict_pe1_c_table = pd.DataFrame({'pe1_c':emotion, dic_y_emotion[0]:Angry_cp_pe1_c, dic_y_emotion[1]:Disgust_cp_pe1_c, dic_y_emotion[2]:Fear_cp_pe1_c, dic_y_emotion[3]:Happy_cp_pe1_c, dic_y_emotion[4]:Neutral_cp_pe1_c, dic_y_emotion[5]:Sad_cp_pe1_c, dic_y_emotion[6]:Surprise_cp_pe1_c})
clasif_predict_pe1_c_table
# Out:
#       pe1_c  Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# 0   Disgust      0        1     0      0        0    0         0
# 1      Fear      0        0     1      0        0    0         0
# 2       Sad      0        0     0      0        0    1         0
# 3   Neutral      0        0     0      0        1    0         0
# 4  Surprise      0        0     0      0        0    0         1
# 5     Angry      1        0     0      0        0    0         0
# 6     Happy      0        0     0      1        0    0         0

# %%
predict_y_emotion_pe1_c_table = pd.DataFrame({'pe1_c':emotion,'Emotion':predict_y_emotion_pe1_c})
predict_y_emotion_pe1_c_table
# Out:
#       pe1_c   Emotion
# 0   Disgust   Disgust
# 1      Fear      Fear
# 2       Sad       Sad
# 3   Neutral   Neutral
# 4  Surprise  Surprise
# 5     Angry     Angry
# 6     Happy     Happy

# %% [markdown]
# ## Tabla de prediccion pe2

# %%
Angry_p_pe2_c, Disgust_p_pe2_c, Fear_p_pe2_c, Happy_p_pe2_c, Neutral_p_pe2_c, Sad_p_pe2_c, Surprise_p_pe2_c, pe2_c = [0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7

for i in range(len(predict_pe2_c)):
  Angry_p_pe2_c[i] = predict_pe2_c[i][0]
  Disgust_p_pe2_c[i] = predict_pe2_c[i][1]
  Fear_p_pe2_c[i] = predict_pe2_c[i][2]
  Happy_p_pe2_c[i] = predict_pe2_c[i][3]
  Neutral_p_pe2_c[i] = predict_pe2_c[i][4]
  Sad_p_pe2_c[i] = predict_pe2_c[i][5]
  Surprise_p_pe2_c[i] = predict_pe2_c[i][6]

for j in range(7):
  pe2_c[i] = dic_y_emotion[j]

predict_pe2_c_table = pd.DataFrame({'pe2_c':emotion, dic_y_emotion[0]:Angry_p_pe2_c, dic_y_emotion[1]:Disgust_p_pe2_c, dic_y_emotion[2]:Fear_p_pe2_c, dic_y_emotion[3]:Happy_p_pe2_c, dic_y_emotion[4]:Neutral_p_pe2_c, dic_y_emotion[5]:Sad_p_pe2_c, dic_y_emotion[6]:Surprise_p_pe2_c})
predict_pe2_c_table
# Out:
#       pe2_c         Angry   Disgust          Fear         Happy       Neutral  \
# 0   Disgust  7.846375e-10  1.000000  7.031396e-09  9.162220e-10  9.831690e-10
# 1      Fear  1.074199e-04  0.005546  9.917509e-01  9.201454e-04  3.356943e-04
# 2       Sad  3.097630e-04  0.001908  4.661551e-05  3.493347e-04  2.639953e-03
# 3   Neutral  6.291153e-07  0.000204  4.727157e-08  7.906136e-05  9.997029e-01
# 4  Surprise  8.444058e-06  0.000012  1.488527e-05  7.753286e-06  2.201236e-07
# 5     Angry  9.662741e-01  0.030596  1.563456e-04  9.429937e-04  5.245515e-04
# 6     Happy  6.708865e-07  0.000024  8.576057e-09  9.999748e-01  2.446603e-08
#
#             Sad      Surprise
# 0  1.975942e-08  6.953518e-10
# 1  1.047069e-03  2.931857e-04
# 2  9.946882e-01  5.838041e-05
# 3  9.389902e-06  4.452266e-06
# 4  4.646864e-05  9.999106e-01
# 5  1.296268e-03  2.100447e-04
# 6  3.866072e-08  8.955118e-09

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe2

# %%
Angry_cp_pe2_c, Disgust_cp_pe2_c, Fear_cp_pe2_c, Happy_cp_pe2_c, Neutral_cp_pe2_c, Sad_cp_pe2_c, Surprise_cp_pe2_c, pe2_c = [0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7
predict_y_pe2_c = np.zeros((7,7))
predict_y_emotion_pe2_c = [0]*7

for i in range(len(predict_pe2_c)):
  predict_y_pe2_c[i][np.argmax(predict_pe2_c[i])] = 1
  predict_y_emotion_pe2_c[i] = dic_y_emotion[np.argmax(predict_pe2_c[i])]

for i in range(len(predict_y_pe2_c)):
  Angry_cp_pe2_c[i] = int(predict_y_pe2_c[i][0])
  Disgust_cp_pe2_c[i] = int(predict_y_pe2_c[i][1])
  Fear_cp_pe2_c[i] = int(predict_y_pe2_c[i][2])
  Happy_cp_pe2_c[i] = int(predict_y_pe2_c[i][3])
  Neutral_cp_pe2_c[i] = int(predict_y_pe2_c[i][4])
  Sad_cp_pe2_c[i] = int(predict_y_pe2_c[i][5])
  Surprise_cp_pe2_c[i] = int(predict_y_pe2_c[i][6])

clasif_predict_pe2_c_table = pd.DataFrame({'pe2_c':emotion, dic_y_emotion[0]:Angry_cp_pe2_c, dic_y_emotion[1]:Disgust_cp_pe2_c, dic_y_emotion[2]:Fear_cp_pe2_c, dic_y_emotion[3]:Happy_cp_pe2_c, dic_y_emotion[4]:Neutral_cp_pe2_c, dic_y_emotion[5]:Sad_cp_pe2_c, dic_y_emotion[6]:Surprise_cp_pe2_c})
clasif_predict_pe2_c_table
# Out:
#       pe2_c  Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# 0   Disgust      0        1     0      0        0    0         0
# 1      Fear      0        0     1      0        0    0         0
# 2       Sad      0        0     0      0        0    1         0
# 3   Neutral      0        0     0      0        1    0         0
# 4  Surprise      0        0     0      0        0    0         1
# 5     Angry      1        0     0      0        0    0         0
# 6     Happy      0        0     0      1        0    0         0

# %%
predict_y_emotion_pe2_c_table = pd.DataFrame({'pe2_c':emotion,'Emotion':predict_y_emotion_pe2_c})
predict_y_emotion_pe2_c_table
# Out:
#       pe2_c   Emotion
# 0   Disgust   Disgust
# 1      Fear      Fear
# 2       Sad       Sad
# 3   Neutral   Neutral
# 4  Surprise  Surprise
# 5     Angry     Angry
# 6     Happy     Happy

# %% [markdown]
# # Tablas de predicciones y clasificacion con Entrenamiento_pe1

# %% [markdown]
# ## Tabla de prediccion pe1

# %%
Angry_p_pe1_pe1, Disgust_p_pe1_pe1, Fear_p_pe1_pe1, Happy_p_pe1_pe1, Neutral_p_pe1_pe1, Sad_p_pe1_pe1, Surprise_p_pe1_pe1, pe1_pe1 = [0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7

for i in range(len(predict_pe1_pe1)):
  Angry_p_pe1_pe1[i] = predict_pe1_pe1[i][0]
  Disgust_p_pe1_pe1[i] = predict_pe1_pe1[i][1]
  Fear_p_pe1_pe1[i] = predict_pe1_pe1[i][2]
  Happy_p_pe1_pe1[i] = predict_pe1_pe1[i][3]
  Neutral_p_pe1_pe1[i] = predict_pe1_pe1[i][4]
  Sad_p_pe1_pe1[i] = predict_pe1_pe1[i][5]
  Surprise_p_pe1_pe1[i] = predict_pe1_pe1[i][6]

for j in range(7):
  pe1_pe1[i] = dic_y_emotion[j]

predict_pe1_pe1_table = pd.DataFrame({'pe1_pe1':emotion, dic_y_emotion[0]:Angry_p_pe1_pe1, dic_y_emotion[1]:Disgust_p_pe1_pe1, dic_y_emotion[2]:Fear_p_pe1_pe1, dic_y_emotion[3]:Happy_p_pe1_pe1, dic_y_emotion[4]:Neutral_p_pe1_pe1, dic_y_emotion[5]:Sad_p_pe1_pe1, dic_y_emotion[6]:Surprise_p_pe1_pe1})
predict_pe1_pe1_table
# Out:
#     pe1_pe1     Angry   Disgust      Fear     Happy   Neutral       Sad  \
# 0   Disgust  0.000963  0.983521  0.000390  0.000086  0.000350  0.014335
# 1      Fear  0.100097  0.279834  0.348862  0.008762  0.036442  0.195282
# 2       Sad  0.288428  0.202351  0.011095  0.003761  0.022644  0.467944
# 3   Neutral  0.081910  0.151024  0.004624  0.019601  0.319453  0.412825
# 4  Surprise  0.000747  0.008490  0.064565  0.002199  0.004422  0.003606
# 5     Angry  0.493816  0.171749  0.007577  0.009759  0.035743  0.275220
# 6     Happy  0.003321  0.059259  0.010758  0.861700  0.031848  0.027662
#
#    Surprise
# 0  0.000354
# 1  0.030721
# 2  0.003778
# 3  0.010563
# 4  0.915971
# 5  0.006136
# 6  0.005453

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe1

# %%
Angry_cp_pe1_pe1, Disgust_cp_pe1_pe1, Fear_cp_pe1_pe1, Happy_cp_pe1_pe1, Neutral_cp_pe1_pe1, Sad_cp_pe1_pe1, Surprise_cp_pe1_pe1, pe1_pe1 = [0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7
predict_y_pe1_pe1 = np.zeros((7,7))
predict_y_emotion_pe1_pe1 = [0]*7

for i in range(len(predict_pe1_pe1)):
  predict_y_pe1_pe1[i][np.argmax(predict_pe1_pe1[i])] = 1
  predict_y_emotion_pe1_pe1[i] = dic_y_emotion[np.argmax(predict_pe1_pe1[i])]

for i in range(len(predict_y_pe1_pe1)):
  Angry_cp_pe1_pe1[i] = int(predict_y_pe1_pe1[i][0])
  Disgust_cp_pe1_pe1[i] = int(predict_y_pe1_pe1[i][1])
  Fear_cp_pe1_pe1[i] = int(predict_y_pe1_pe1[i][2])
  Happy_cp_pe1_pe1[i] = int(predict_y_pe1_pe1[i][3])
  Neutral_cp_pe1_pe1[i] = int(predict_y_pe1_pe1[i][4])
  Sad_cp_pe1_pe1[i] = int(predict_y_pe1_pe1[i][5])
  Surprise_cp_pe1_pe1[i] = int(predict_y_pe1_pe1[i][6])

clasif_predict_pe1_pe1_table = pd.DataFrame({'pe1_pe1':emotion, dic_y_emotion[0]:Angry_cp_pe1_pe1, dic_y_emotion[1]:Disgust_cp_pe1_pe1, dic_y_emotion[2]:Fear_cp_pe1_pe1, dic_y_emotion[3]:Happy_cp_pe1_pe1, dic_y_emotion[4]:Neutral_cp_pe1_pe1, dic_y_emotion[5]:Sad_cp_pe1_pe1, dic_y_emotion[6]:Surprise_cp_pe1_pe1})
clasif_predict_pe1_pe1_table
# Out:
#     pe1_pe1  Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# 0   Disgust      0        1     0      0        0    0         0
# 1      Fear      0        0     1      0        0    0         0
# 2       Sad      0        0     0      0        0    1         0
# 3   Neutral      0        0     0      0        0    1         0
# 4  Surprise      0        0     0      0        0    0         1
# 5     Angry      1        0     0      0        0    0         0
# 6     Happy      0        0     0      1        0    0         0

# %%
predict_y_emotion_pe1_pe1_table = pd.DataFrame({'pe1_pe1':emotion,'Emotion':predict_y_emotion_pe1_pe1})
predict_y_emotion_pe1_pe1_table
# Out:
#     pe1_pe1   Emotion
# 0   Disgust   Disgust
# 1      Fear      Fear
# 2       Sad       Sad
# 3   Neutral       Sad
# 4  Surprise  Surprise
# 5     Angry     Angry
# 6     Happy     Happy

# %% [markdown]
# ## Tabla de prediccion pe2

# %%
Angry_pe2_pe1, Disgust_pe2_pe1, Fear_pe2_pe1, Happy_pe2_pe1, Neutral_pe2_pe1, Sad_pe2_pe1, Surprise_pe2_pe1, pe2_pe1 = [],[],[],[],[],[],[],[]

for i in predict_pe2_pe1:
  Angry_pe2_pe1.append(i[0])
  Disgust_pe2_pe1.append(i[1])
  Fear_pe2_pe1.append(i[2])
  Happy_pe2_pe1.append(i[3])
  Neutral_pe2_pe1.append(i[4])
  Sad_pe2_pe1.append(i[5])
  Surprise_pe2_pe1.append(i[6])

for j in range(7):
  pe2_pe1.append(dic_y_emotion[j])

predict_pe2_pe1_table = pd.DataFrame({'pe2_pe1':emotion, dic_y_emotion[0]:Angry_pe2_pe1, dic_y_emotion[1]:Disgust_pe2_pe1, dic_y_emotion[2]:Fear_pe2_pe1, dic_y_emotion[3]:Happy_pe2_pe1, dic_y_emotion[4]:Neutral_pe2_pe1, dic_y_emotion[5]:Sad_pe2_pe1, dic_y_emotion[6]:Surprise_pe2_pe1})
predict_pe2_pe1_table
# Out:
#     pe2_pe1         Angry   Disgust      Fear     Happy   Neutral       Sad  \
# 0   Disgust  3.099377e-07  0.999800  0.000021  0.000018  0.000023  0.000078
# 1      Fear  1.557875e-02  0.105674  0.828968  0.008699  0.010172  0.026080
# 2       Sad  6.483302e-03  0.089997  0.004986  0.006056  0.004805  0.885812
# 3   Neutral  3.424562e-01  0.028199  0.016548  0.023393  0.525335  0.056552
# 4  Surprise  1.018372e-04  0.000701  0.002765  0.001042  0.001981  0.000572
# 5     Angry  9.946223e-01  0.000979  0.000356  0.000579  0.001864  0.001449
# 6     Happy  8.886831e-04  0.003895  0.003578  0.983448  0.001886  0.006034
#
#    Surprise
# 0  0.000061
# 1  0.004829
# 2  0.001862
# 3  0.007517
# 4  0.992837
# 5  0.000151
# 6  0.000271

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe2

# %%
Angry_cp_pe2_pe1, Disgust_cp_pe2_pe1, Fear_cp_pe2_pe1, Happy_cp_pe2_pe1, Neutral_cp_pe2_pe1, Sad_cp_pe2_pe1, Surprise_cp_pe2_pe1, pe2_pe1 = [0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7
predict_y_pe2_pe1 = np.zeros((7,7))
predict_y_emotion_pe2_pe1 = [0]*7

for i in range(len(predict_pe2_pe1)):
  predict_y_pe2_pe1[i][np.argmax(predict_pe2_pe1[i])] = 1
  predict_y_emotion_pe2_pe1[i] = dic_y_emotion[np.argmax(predict_pe2_pe1[i])]

for i in range(len(predict_y_pe2_pe1)):
  Angry_cp_pe2_pe1[i] = int(predict_y_pe2_pe1[i][0])
  Disgust_cp_pe2_pe1[i] = int(predict_y_pe2_pe1[i][1])
  Fear_cp_pe2_pe1[i] = int(predict_y_pe2_pe1[i][2])
  Happy_cp_pe2_pe1[i] = int(predict_y_pe2_pe1[i][3])
  Neutral_cp_pe2_pe1[i] = int(predict_y_pe2_pe1[i][4])
  Sad_cp_pe2_pe1[i] = int(predict_y_pe2_pe1[i][5])
  Surprise_cp_pe2_pe1[i] = int(predict_y_pe2_pe1[i][6])

clasif_predict_pe2_pe1_table = pd.DataFrame({'pe2_pe1':emotion, dic_y_emotion[0]:Angry_cp_pe2_pe1, dic_y_emotion[1]:Disgust_cp_pe2_pe1, dic_y_emotion[2]:Fear_cp_pe2_pe1, dic_y_emotion[3]:Happy_cp_pe2_pe1, dic_y_emotion[4]:Neutral_cp_pe2_pe1, dic_y_emotion[5]:Sad_cp_pe2_pe1, dic_y_emotion[6]:Surprise_cp_pe2_pe1})
clasif_predict_pe2_pe1_table
# Out:
#     pe2_pe1  Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# 0   Disgust      0        1     0      0        0    0         0
# 1      Fear      0        0     1      0        0    0         0
# 2       Sad      0        0     0      0        0    1         0
# 3   Neutral      0        0     0      0        1    0         0
# 4  Surprise      0        0     0      0        0    0         1
# 5     Angry      1        0     0      0        0    0         0
# 6     Happy      0        0     0      1        0    0         0

# %%
predict_y_emotion_pe2_pe1_table = pd.DataFrame({'pe2_pe1':emotion,'Emotion':predict_y_emotion_pe2_pe1})
predict_y_emotion_pe2_pe1_table
# Out:
#     pe2_pe1   Emotion
# 0   Disgust   Disgust
# 1      Fear      Fear
# 2       Sad       Sad
# 3   Neutral   Neutral
# 4  Surprise  Surprise
# 5     Angry     Angry
# 6     Happy     Happy

# %% [markdown]
# # Tablas de predicciones y clasificacion con Entrenamiento_pe2

# %% [markdown]
# ## Tabla de prediccion pe1

# %%
Angry_pe1_pe2, Disgust_pe1_pe2, Fear_pe1_pe2, Happy_pe1_pe2, Neutral_pe1_pe2, Sad_pe1_pe2, Surprise_pe1_pe2, pe1_pe2 = [],[],[],[],[],[],[],[]

for i in predict_pe1_pe2:
  Angry_pe1_pe2.append(i[0])
  Disgust_pe1_pe2.append(i[1])
  Fear_pe1_pe2.append(i[2])
  Happy_pe1_pe2.append(i[3])
  Neutral_pe1_pe2.append(i[4])
  Sad_pe1_pe2.append(i[5])
  Surprise_pe1_pe2.append(i[6])

for j in range(7):
  pe1_pe2.append(dic_y_emotion[j])

predict_pe1_pe2_table = pd.DataFrame({'pe1_pe2':emotion, dic_y_emotion[0]:Angry_pe1_pe2, dic_y_emotion[1]:Disgust_pe1_pe2, dic_y_emotion[2]:Fear_pe1_pe2, dic_y_emotion[3]:Happy_pe1_pe2, dic_y_emotion[4]:Neutral_pe1_pe2, dic_y_emotion[5]:Sad_pe1_pe2, dic_y_emotion[6]:Surprise_pe1_pe2})
predict_pe1_pe2_table
# Out:
#     pe1_pe2     Angry   Disgust      Fear     Happy   Neutral       Sad  \
# 0   Disgust  0.000279  0.978765  0.000284  0.000068  0.000225  0.020151
# 1      Fear  0.018520  0.109090  0.008112  0.002254  0.003722  0.857375
# 2       Sad  0.002887  0.068055  0.000656  0.000331  0.000499  0.927417
# 3   Neutral  0.010515  0.135873  0.003426  0.011744  0.328516  0.485394
# 4  Surprise  0.000134  0.015621  0.000244  0.000689  0.035114  0.004751
# 5     Angry  0.809924  0.043196  0.001303  0.001255  0.003121  0.140490
# 6     Happy  0.001512  0.004655  0.000343  0.991746  0.000213  0.000299
#
#    Surprise
# 0  0.000228
# 1  0.000927
# 2  0.000155
# 3  0.024532
# 4  0.943447
# 5  0.000711
# 6  0.001234

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe1

# %%
Angry_cp_pe1_pe2, Disgust_cp_pe1_pe2, Fear_cp_pe1_pe2, Happy_cp_pe1_pe2, Neutral_cp_pe1_pe2, Sad_cp_pe1_pe2, Surprise_cp_pe1_pe2, pe1_pe2 = [0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7
predict_y_pe1_pe2 = np.zeros((7,7))
predict_y_emotion_pe1_pe2 = [0]*7

for i in range(len(predict_pe1_pe2)):
  predict_y_pe1_pe2[i][np.argmax(predict_pe1_pe2[i])] = 1
  predict_y_emotion_pe1_pe2[i] = dic_y_emotion[np.argmax(predict_pe1_pe2[i])]

for i in range(len(predict_y_pe1_pe2)):
  Angry_cp_pe1_pe2[i] = int(predict_y_pe1_pe2[i][0])
  Disgust_cp_pe1_pe2[i] = int(predict_y_pe1_pe2[i][1])
  Fear_cp_pe1_pe2[i] = int(predict_y_pe1_pe2[i][2])
  Happy_cp_pe1_pe2[i] = int(predict_y_pe1_pe2[i][3])
  Neutral_cp_pe1_pe2[i] = int(predict_y_pe1_pe2[i][4])
  Sad_cp_pe1_pe2[i] = int(predict_y_pe1_pe2[i][5])
  Surprise_cp_pe1_pe2[i] = int(predict_y_pe1_pe2[i][6])

clasif_predict_pe1_pe2_table = pd.DataFrame({'pe1_pe2':emotion, dic_y_emotion[0]:Angry_cp_pe1_pe2, dic_y_emotion[1]:Disgust_cp_pe1_pe2, dic_y_emotion[2]:Fear_cp_pe1_pe2, dic_y_emotion[3]:Happy_cp_pe1_pe2, dic_y_emotion[4]:Neutral_cp_pe1_pe2, dic_y_emotion[5]:Sad_cp_pe1_pe2, dic_y_emotion[6]:Surprise_cp_pe1_pe2})
clasif_predict_pe1_pe2_table
# Out:
#     pe1_pe2  Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# 0   Disgust      0        1     0      0        0    0         0
# 1      Fear      0        0     0      0        0    1         0
# 2       Sad      0        0     0      0        0    1         0
# 3   Neutral      0        0     0      0        0    1         0
# 4  Surprise      0        0     0      0        0    0         1
# 5     Angry      1        0     0      0        0    0         0
# 6     Happy      0        0     0      1        0    0         0

# %%
predict_y_emotion_pe1_pe2_table = pd.DataFrame({'pe1_pe2':emotion,'Emotion':predict_y_emotion_pe1_pe2})
predict_y_emotion_pe1_pe2_table
# Out:
#     pe1_pe2   Emotion
# 0   Disgust   Disgust
# 1      Fear       Sad
# 2       Sad       Sad
# 3   Neutral       Sad
# 4  Surprise  Surprise
# 5     Angry     Angry
# 6     Happy     Happy

# %% [markdown]
# ## Tabla de prediccion pe2

# %%
Angry_pe2_pe2, Disgust_pe2_pe2, Fear_pe2_pe2, Happy_pe2_pe2, Neutral_pe2_pe2, Sad_pe2_pe2, Surprise_pe2_pe2, pe2_pe2 = [],[],[],[],[],[],[],[]

for i in predict_pe2_pe2:
  Angry_pe2_pe2.append(i[0])
  Disgust_pe2_pe2.append(i[1])
  Fear_pe2_pe2.append(i[2])
  Happy_pe2_pe2.append(i[3])
  Neutral_pe2_pe2.append(i[4])
  Sad_pe2_pe2.append(i[5])
  Surprise_pe2_pe2.append(i[6])

for j in range(7):
  pe2_pe2.append(dic_y_emotion[j])

predict_pe2_pe2_table = pd.DataFrame({'pe2_pe2':emotion, dic_y_emotion[0]:Angry_pe2_pe2, dic_y_emotion[1]:Disgust_pe2_pe2, dic_y_emotion[2]:Fear_pe2_pe2, dic_y_emotion[3]:Happy_pe2_pe2, dic_y_emotion[4]:Neutral_pe2_pe2, dic_y_emotion[5]:Sad_pe2_pe2, dic_y_emotion[6]:Surprise_pe2_pe2})
predict_pe2_pe2_table
# Out:
#     pe2_pe2     Angry   Disgust      Fear     Happy   Neutral       Sad  \
# 0   Disgust  0.000020  0.584802  0.000250  0.000020  0.000133  0.414716
# 1      Fear  0.000619  0.300874  0.044886  0.007131  0.006855  0.638496
# 2       Sad  0.000755  0.056227  0.011181  0.001593  0.003882  0.925751
# 3   Neutral  0.012710  0.103215  0.014607  0.067341  0.346668  0.417997
# 4  Surprise  0.000101  0.006222  0.001042  0.000529  0.003554  0.001227
# 5     Angry  0.012720  0.008075  0.002323  0.001295  0.001642  0.973576
# 6     Happy  0.005486  0.002062  0.022851  0.965593  0.000254  0.003417
#
#    Surprise
# 0  0.000058
# 1  0.001139
# 2  0.000612
# 3  0.037461
# 4  0.987324
# 5  0.000369
# 6  0.000337

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe2

# %%
Angry_cp_pe2_pe2, Disgust_cp_pe2_pe2, Fear_cp_pe2_pe2, Happy_cp_pe2_pe2, Neutral_cp_pe2_pe2, Sad_cp_pe2_pe2, Surprise_cp_pe2_pe2, pe2_pe2 = [0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7
predict_y_pe2_pe2 = np.zeros((7,7))
predict_y_emotion_pe2_pe2 = [0]*7

for i in range(len(predict_pe2_pe2)):
  predict_y_pe2_pe2[i][np.argmax(predict_pe2_pe2[i])] = 1
  predict_y_emotion_pe2_pe2[i] = dic_y_emotion[np.argmax(predict_pe2_pe2[i])]

for i in range(len(predict_y_pe2_pe2)):
  Angry_cp_pe2_pe2[i] = int(predict_y_pe2_pe2[i][0])
  Disgust_cp_pe2_pe2[i] = int(predict_y_pe2_pe2[i][1])
  Fear_cp_pe2_pe2[i] = int(predict_y_pe2_pe2[i][2])
  Happy_cp_pe2_pe2[i] = int(predict_y_pe2_pe2[i][3])
  Neutral_cp_pe2_pe2[i] = int(predict_y_pe2_pe2[i][4])
  Sad_cp_pe2_pe2[i] = int(predict_y_pe2_pe2[i][5])
  Surprise_cp_pe2_pe2[i] = int(predict_y_pe2_pe2[i][6])

clasif_predict_pe2_pe2_table = pd.DataFrame({'pe2_pe2':emotion, dic_y_emotion[0]:Angry_cp_pe2_pe2, dic_y_emotion[1]:Disgust_cp_pe2_pe2, dic_y_emotion[2]:Fear_cp_pe2_pe2, dic_y_emotion[3]:Happy_cp_pe2_pe2, dic_y_emotion[4]:Neutral_cp_pe2_pe2, dic_y_emotion[5]:Sad_cp_pe2_pe2, dic_y_emotion[6]:Surprise_cp_pe2_pe2})
clasif_predict_pe2_pe2_table
# Out:
#     pe2_pe2  Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# 0   Disgust      0        1     0      0        0    0         0
# 1      Fear      0        0     0      0        0    1         0
# 2       Sad      0        0     0      0        0    1         0
# 3   Neutral      0        0     0      0        0    1         0
# 4  Surprise      0        0     0      0        0    0         1
# 5     Angry      0        0     0      0        0    1         0
# 6     Happy      0        0     0      1        0    0         0

# %%
predict_y_emotion_pe2_pe2_table = pd.DataFrame({'pe2_pe2':emotion,'Emotion':predict_y_emotion_pe2_pe2})
predict_y_emotion_pe2_pe2_table
# Out:
#     pe2_pe2   Emotion
# 0   Disgust   Disgust
# 1      Fear       Sad
# 2       Sad       Sad
# 3   Neutral       Sad
# 4  Surprise  Surprise
# 5     Angry       Sad
# 6     Happy     Happy

# %% [markdown]
# # Tablas de predicciones y clasificacion con Entrenamiento_pe12

# %% [markdown]
# ## Tabla de prediccion pe1

# %%
Angry_pe1_pe12, Disgust_pe1_pe12, Fear_pe1_pe12, Happy_pe1_pe12, Neutral_pe1_pe12, Sad_pe1_pe12, Surprise_pe1_pe12, pe1_pe12 = [],[],[],[],[],[],[],[]

for i in predict_pe1_pe12:
  Angry_pe1_pe12.append(i[0])
  Disgust_pe1_pe12.append(i[1])
  Fear_pe1_pe12.append(i[2])
  Happy_pe1_pe12.append(i[3])
  Neutral_pe1_pe12.append(i[4])
  Sad_pe1_pe12.append(i[5])
  Surprise_pe1_pe12.append(i[6])

for j in range(7):
  pe1_pe12.append(dic_y_emotion[j])

predict_pe1_pe12_table = pd.DataFrame({'pe1_pe12':emotion, dic_y_emotion[0]:Angry_pe1_pe12, dic_y_emotion[1]:Disgust_pe1_pe12, dic_y_emotion[2]:Fear_pe1_pe12, dic_y_emotion[3]:Happy_pe1_pe12, dic_y_emotion[4]:Neutral_pe1_pe12, dic_y_emotion[5]:Sad_pe1_pe12, dic_y_emotion[6]:Surprise_pe1_pe12})
predict_pe1_pe12_table
# Out:
#    pe1_pe12     Angry   Disgust      Fear     Happy   Neutral       Sad  \
# 0   Disgust  0.151806  0.218657  0.092757  0.096598  0.144825  0.222001
# 1      Fear  0.171087  0.198728  0.099889  0.094907  0.131034  0.219802
# 2       Sad  0.188201  0.189071  0.094933  0.110143  0.144466  0.203521
# 3   Neutral  0.187175  0.217107  0.094918  0.101930  0.120911  0.204053
# 4  Surprise  0.143633  0.203623  0.107983  0.108342  0.141571  0.205574
# 5     Angry  0.189466  0.205534  0.089421  0.103703  0.119502  0.222291
# 6     Happy  0.157658  0.166810  0.139110  0.128406  0.112704  0.208991
#
#    Surprise
# 0  0.073356
# 1  0.084554
# 2  0.069665
# 3  0.073906
# 4  0.089275
# 5  0.070082
# 6  0.086320

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe1

# %%
Angry_cp_pe1_pe12, Disgust_cp_pe1_pe12, Fear_cp_pe1_pe12, Happy_cp_pe1_pe12, Neutral_cp_pe1_pe12, Sad_cp_pe1_pe12, Surprise_cp_pe1_pe12, pe1_pe12 = [0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7
predict_y_pe1_pe12 = np.zeros((7,7))
predict_y_emotion_pe1_pe12 = [0]*7

for i in range(len(predict_pe1_pe12)):
  predict_y_pe1_pe12[i][np.argmax(predict_pe1_pe12[i])] = 1
  predict_y_emotion_pe1_pe12[i] = dic_y_emotion[np.argmax(predict_pe1_pe12[i])]

for i in range(len(predict_y_pe1_pe12)):
  Angry_cp_pe1_pe12[i] = int(predict_y_pe1_pe12[i][0])
  Disgust_cp_pe1_pe12[i] = int(predict_y_pe1_pe12[i][1])
  Fear_cp_pe1_pe12[i] = int(predict_y_pe1_pe12[i][2])
  Happy_cp_pe1_pe12[i] = int(predict_y_pe1_pe12[i][3])
  Neutral_cp_pe1_pe12[i] = int(predict_y_pe1_pe12[i][4])
  Sad_cp_pe1_pe12[i] = int(predict_y_pe1_pe12[i][5])
  Surprise_cp_pe1_pe12[i] = int(predict_y_pe1_pe12[i][6])

clasif_predict_pe1_pe12_table = pd.DataFrame({'pe1_pe12':emotion, dic_y_emotion[0]:Angry_cp_pe1_pe12, dic_y_emotion[1]:Disgust_cp_pe1_pe12, dic_y_emotion[2]:Fear_cp_pe1_pe12, dic_y_emotion[3]:Happy_cp_pe1_pe12, dic_y_emotion[4]:Neutral_cp_pe1_pe12, dic_y_emotion[5]:Sad_cp_pe1_pe12, dic_y_emotion[6]:Surprise_cp_pe1_pe12})
clasif_predict_pe1_pe12_table
# Out:
#    pe1_pe12  Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# 0   Disgust      0        0     0      0        0    1         0
# 1      Fear      0        0     0      0        0    1         0
# 2       Sad      0        0     0      0        0    1         0
# 3   Neutral      0        1     0      0        0    0         0
# 4  Surprise      0        0     0      0        0    1         0
# 5     Angry      0        0     0      0        0    1         0
# 6     Happy      0        0     0      0        0    1         0

# %%
predict_y_emotion_pe1_pe12_table = pd.DataFrame({'pe1_pe12':emotion,'Emotion':predict_y_emotion_pe1_pe12})
predict_y_emotion_pe1_pe12_table
# Out:
#    pe1_pe12  Emotion
# 0   Disgust      Sad
# 1      Fear      Sad
# 2       Sad      Sad
# 3   Neutral  Disgust
# 4  Surprise      Sad
# 5     Angry      Sad
# 6     Happy      Sad

# %% [markdown]
# ## Tabla de prediccion pe2

# %%
Angry_pe2_pe12, Disgust_pe2_pe12, Fear_pe2_pe12, Happy_pe2_pe12, Neutral_pe2_pe12, Sad_pe2_pe12, Surprise_pe2_pe12, pe2_pe12 = [],[],[],[],[],[],[],[]

for i in predict_pe2_pe12:
  Angry_pe2_pe12.append(i[0])
  Disgust_pe2_pe12.append(i[1])
  Fear_pe2_pe12.append(i[2])
  Happy_pe2_pe12.append(i[3])
  Neutral_pe2_pe12.append(i[4])
  Sad_pe2_pe12.append(i[5])
  Surprise_pe2_pe12.append(i[6])

for j in range(7):
  pe2_pe12.append(dic_y_emotion[j])

predict_pe2_pe12_table = pd.DataFrame({'pe2_pe12':emotion, dic_y_emotion[0]:Angry_pe2_pe12, dic_y_emotion[1]:Disgust_pe2_pe12, dic_y_emotion[2]:Fear_pe2_pe12, dic_y_emotion[3]:Happy_pe2_pe12, dic_y_emotion[4]:Neutral_pe2_pe12, dic_y_emotion[5]:Sad_pe2_pe12, dic_y_emotion[6]:Surprise_pe2_pe12})
predict_pe2_pe12_table
# Out:
#    pe2_pe12     Angry   Disgust      Fear     Happy   Neutral       Sad  \
# 0   Disgust  0.180439  0.226235  0.090504  0.099842  0.134490  0.205709
# 1      Fear  0.173971  0.239491  0.099815  0.087988  0.096563  0.224188
# 2       Sad  0.172362  0.221097  0.095809  0.108571  0.137437  0.192038
# 3   Neutral  0.199109  0.238186  0.081701  0.087620  0.116354  0.211111
# 4  Surprise  0.186466  0.247098  0.097954  0.085303  0.099995  0.208736
# 5     Angry  0.186713  0.228082  0.093517  0.098253  0.129420  0.200841
# 6     Happy  0.164769  0.221666  0.094459  0.102588  0.136616  0.210404
#
#    Surprise
# 0  0.062781
# 1  0.077985
# 2  0.072687
# 3  0.065920
# 4  0.074448
# 5  0.063175
# 6  0.069496

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe2

# %%
Angry_cp_pe2_pe12, Disgust_cp_pe2_pe12, Fear_cp_pe2_pe12, Happy_cp_pe2_pe12, Neutral_cp_pe2_pe12, Sad_cp_pe2_pe12, Surprise_cp_pe2_pe12, pe2_pe12 = [0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7,[0]*7
predict_y_pe2_pe12 = np.zeros((7,7))
predict_y_emotion_pe2_pe12 = [0]*7

for i in range(len(predict_pe2_pe12)):
  predict_y_pe2_pe12[i][np.argmax(predict_pe2_pe12[i])] = 1
  predict_y_emotion_pe2_pe12[i] = dic_y_emotion[np.argmax(predict_pe2_pe12[i])]

for i in range(len(predict_y_pe2_pe12)):
  Angry_cp_pe2_pe12[i] = int(predict_y_pe2_pe12[i][0])
  Disgust_cp_pe2_pe12[i] = int(predict_y_pe2_pe12[i][1])
  Fear_cp_pe2_pe12[i] = int(predict_y_pe2_pe12[i][2])
  Happy_cp_pe2_pe12[i] = int(predict_y_pe2_pe12[i][3])
  Neutral_cp_pe2_pe12[i] = int(predict_y_pe2_pe12[i][4])
  Sad_cp_pe2_pe12[i] = int(predict_y_pe2_pe12[i][5])
  Surprise_cp_pe2_pe12[i] = int(predict_y_pe2_pe12[i][6])

clasif_predict_pe2_pe12_table = pd.DataFrame({'pe2_pe12':emotion, dic_y_emotion[0]:Angry_cp_pe2_pe12, dic_y_emotion[1]:Disgust_cp_pe2_pe12, dic_y_emotion[2]:Fear_cp_pe2_pe12, dic_y_emotion[3]:Happy_cp_pe2_pe12, dic_y_emotion[4]:Neutral_cp_pe2_pe12, dic_y_emotion[5]:Sad_cp_pe2_pe12, dic_y_emotion[6]:Surprise_cp_pe2_pe12})
clasif_predict_pe2_pe12_table
# Out:
#    pe2_pe12  Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# 0   Disgust      0        1     0      0        0    0         0
# 1      Fear      0        1     0      0        0    0         0
# 2       Sad      0        1     0      0        0    0         0
# 3   Neutral      0        1     0      0        0    0         0
# 4  Surprise      0        1     0      0        0    0         0
# 5     Angry      0        1     0      0        0    0         0
# 6     Happy      0        1     0      0        0    0         0

# %%
predict_y_emotion_pe2_pe12_table = pd.DataFrame({'pe2_pe12':emotion,'Emotion':predict_y_emotion_pe2_pe12})
predict_y_emotion_pe2_pe12_table
# Out:
#    pe2_pe12  Emotion
# 0   Disgust  Disgust
# 1      Fear  Disgust
# 2       Sad  Disgust
# 3   Neutral  Disgust
# 4  Surprise  Disgust
# 5     Angry  Disgust
# 6     Happy  Disgust
