# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarJCC/Google-Colab-Professional-Internship-Project-Machine-Learning/blob/main/Show_Result.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
emocion = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/People_Data/Emocion.npy')
y_emocion = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/People_Data/y_Emocion.npy')

# %%
dic_y_emotion = {0:"Angry",
               1:"Disgust",
               2:"Fear",
               3:"Happy",
               4:"Neutral",
               5:"Sad",
               6:"Surprise"}

dic_emotion = {"ANS":"Angry",
               "DIS":"Disgust",
               "AFS":"Fear",
               "HAS":"Happy",
               "NES":"Neutral",
               "SAS":"Sad",
               "SUS":"Surprise"}

df_emotion = pd.DataFrame(dic_emotion.items(), columns=['Codigo', 'Emocion'])
df_emotion
# Out:
#   Codigo   Emocion
# 0    ANS     Angry
# 1    DIS   Disgust
# 2    AFS      Fear
# 3    HAS     Happy
# 4    NES   Neutral
# 5    SAS       Sad
# 6    SUS  Surprise

# %%
emotion = []
for i in emocion:
  emotion.append(dic_emotion[str(i[-3:])])

# %%
people_z_train = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/People_Data/People_z_train.npy')

# %%
result_c = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/Complete_Data/Result.npy')
predict_pe1_c = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/Complete_Data/Predict_pe1.npy')
predict_pe2_c = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/Complete_Data/Predict_pe2.npy')

# %%
result_pe1 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe1_Data/Result.npy')
predict_pe1_pe1 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe1_Data/Predict_pe1.npy')
predict_pe2_pe1 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe1_Data/Predict_pe2.npy')

# %%
result_pe2 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe2_Data/Result.npy')
predict_pe1_pe2 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe2_Data/Predict_pe1.npy')
predict_pe2_pe2 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe2_Data/Predict_pe2.npy')

# %%
result_pe12 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe12_Data/Result.npy')
predict_pe1_pe12 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe12_Data/Predict_pe1.npy')
predict_pe2_pe12 = np.load('/content/drive/My Drive/KDEF_and_AKDEF_R/NrmEfficientNet/Result_Predict/pe12_Data/Predict_pe2.npy')

# %%
c = ['Training acc', 'Validation acc', 'Training loss', 'Validation loss']
e_t = ["Entrenamiento_Completo","Entrenamiento_pe1","Entrenamiento_pe2","Entrenamiento_pe12"]

result_table = pd.DataFrame([result_c,result_pe1,result_pe2,result_pe12],columns = c)

if "Entrenamiento" not in list(result_table.columns.values):
  result_table.insert(0,"Entrenamiento",e_t)
  result_table.set_index("Entrenamiento",inplace = True)

result_table
# Out:
#                         Training acc  Validation acc  Training loss  \
# Entrenamiento
# Entrenamiento_Completo      1.000000        0.714286       1.511212
# Entrenamiento_pe1           0.993088        0.755102       1.310248
# Entrenamiento_pe2           0.988479        0.795918       1.339411
# Entrenamiento_pe12          0.995316        0.795918       1.322884
#
#                         Validation loss
# Entrenamiento
# Entrenamiento_Completo         2.574861
# Entrenamiento_pe1              2.088049
# Entrenamiento_pe2              2.237170
# Entrenamiento_pe12             2.063426

# %% [markdown]
# # Tablas de prediccion y clasificacion con Entrenamiento_Completo

# %% [markdown]
# ## Tabla de prediccion pe1

# %%
predict_pe1_c_table = pd.DataFrame(predict_pe1_c, columns = list(df_emotion["Emocion"]))

if "pe1_c" not in list(predict_pe1_c_table.columns.values):
  predict_pe1_c_table.insert(0,"pe1_c",emotion)
  predict_pe1_c_table.set_index("pe1_c",inplace = True)

predict_pe1_c_table
# Out:
#                  Angry   Disgust          Fear         Happy       Neutral  \
# pe1_c
# Disgust   3.696481e-10  1.000000  6.980819e-08  5.083553e-12  8.033923e-12
# Fear      2.993370e-03  0.057809  8.870340e-01  6.752721e-04  1.477992e-03
# Sad       8.122314e-05  0.006028  1.883476e-05  4.168301e-05  2.091703e-03
# Neutral   9.699919e-07  0.006881  4.082919e-06  1.841780e-04  9.912709e-01
# Surprise  6.787522e-06  0.000049  1.359480e-04  4.570183e-06  1.287394e-05
# Angry     9.212227e-01  0.076432  1.205883e-03  1.454939e-04  4.991813e-04
# Happy     1.684864e-08  0.009769  1.455611e-08  9.902294e-01  1.033233e-07
#
#                    Sad      Surprise
# pe1_c
# Disgust   5.513440e-09  1.477139e-10
# Fear      4.396016e-02  6.050053e-03
# Sad       9.917088e-01  3.005927e-05
# Neutral   1.611811e-03  4.684522e-05
# Surprise  1.216272e-05  9.997790e-01
# Angry     2.636287e-04  2.307133e-04
# Happy     7.410415e-07  2.047894e-07

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe1

# %%
predict_y_pe1_c = np.zeros((7,7))
predict_y_emotion_pe1_c = [0]*7

for i in range(len(predict_pe1_c)):
  predict_y_pe1_c[i][np.argmax(predict_pe1_c[i])] = 1
  predict_y_emotion_pe1_c[i] = dic_y_emotion[np.argmax(predict_pe1_c[i])]

clasif_predict_pe1_c_table = pd.DataFrame(predict_y_pe1_c.astype(int), columns = list(df_emotion["Emocion"]))

if "pe1_c" not in list(clasif_predict_pe1_c_table.columns.values):
  clasif_predict_pe1_c_table.insert(0,"pe1_c",emotion)
  clasif_predict_pe1_c_table.set_index("pe1_c",inplace = True)

clasif_predict_pe1_c_table
# Out:
#           Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# pe1_c
# Disgust       0        1     0      0        0    0         0
# Fear          0        0     1      0        0    0         0
# Sad           0        0     0      0        0    1         0
# Neutral       0        0     0      0        1    0         0
# Surprise      0        0     0      0        0    0         1
# Angry         1        0     0      0        0    0         0
# Happy         0        0     0      1        0    0         0

# %%
predict_y_emotion_pe1_c_table = pd.DataFrame({'pe1_c':emotion,'Emotion':predict_y_emotion_pe1_c})
predict_y_emotion_pe1_c_table.set_index("pe1_c",inplace = True)
predict_y_emotion_pe1_c_table
# Out:
#            Emotion
# pe1_c
# Disgust    Disgust
# Fear          Fear
# Sad            Sad
# Neutral    Neutral
# Surprise  Surprise
# Angry        Angry
# Happy        Happy

# %% [markdown]
# ## Tabla de prediccion pe2

# %%
predict_pe2_c_table = pd.DataFrame(predict_pe2_c, columns = list(df_emotion["Emocion"]))

if "pe2_c" not in list(predict_pe2_c_table.columns.values):
  predict_pe2_c_table.insert(0,"pe2_c",emotion)
  predict_pe2_c_table.set_index("pe2_c",inplace = True)

predict_pe2_c_table
# Out:
#                  Angry   Disgust          Fear         Happy       Neutral  \
# pe2_c
# Disgust   7.846375e-10  1.000000  7.031396e-09  9.162220e-10  9.831690e-10
# Fear      1.074199e-04  0.005546  9.917509e-01  9.201454e-04  3.356943e-04
# Sad       3.097630e-04  0.001908  4.661551e-05  3.493347e-04  2.639953e-03
# Neutral   6.291153e-07  0.000204  4.727157e-08  7.906136e-05  9.997029e-01
# Surprise  8.444058e-06  0.000012  1.488527e-05  7.753286e-06  2.201236e-07
# Angry     9.662741e-01  0.030596  1.563456e-04  9.429937e-04  5.245515e-04
# Happy     6.708865e-07  0.000024  8.576057e-09  9.999748e-01  2.446603e-08
#
#                    Sad      Surprise
# pe2_c
# Disgust   1.975942e-08  6.953518e-10
# Fear      1.047069e-03  2.931857e-04
# Sad       9.946882e-01  5.838041e-05
# Neutral   9.389902e-06  4.452266e-06
# Surprise  4.646864e-05  9.999106e-01
# Angry     1.296268e-03  2.100447e-04
# Happy     3.866072e-08  8.955118e-09

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe2

# %%
predict_y_pe2_c = np.zeros((7,7))
predict_y_emotion_pe2_c = [0]*7

for i in range(len(predict_pe2_c)):
  predict_y_pe2_c[i][np.argmax(predict_pe2_c[i])] = 1
  predict_y_emotion_pe2_c[i] = dic_y_emotion[np.argmax(predict_pe2_c[i])]

clasif_predict_pe2_c_table = pd.DataFrame(predict_y_pe2_c.astype(int), columns = list(df_emotion["Emocion"]))

if "pe2_c" not in list(clasif_predict_pe2_c_table.columns.values):
  clasif_predict_pe2_c_table.insert(0,"pe2_c",emotion)
  clasif_predict_pe2_c_table.set_index("pe2_c",inplace = True)

clasif_predict_pe2_c_table
# Out:
#           Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# pe2_c
# Disgust       0        1     0      0        0    0         0
# Fear          0        0     1      0        0    0         0
# Sad           0        0     0      0        0    1         0
# Neutral       0        0     0      0        1    0         0
# Surprise      0        0     0      0        0    0         1
# Angry         1        0     0      0        0    0         0
# Happy         0        0     0      1        0    0         0

# %%
predict_y_emotion_pe2_c_table = pd.DataFrame({'pe2_c':emotion,'Emotion':predict_y_emotion_pe2_c})
predict_y_emotion_pe2_c_table
# Out:
#       pe2_c   Emotion
# 0   Disgust   Disgust
# 1      Fear      Fear
# 2       Sad       Sad
# 3   Neutral   Neutral
# 4  Surprise  Surprise
# 5     Angry     Angry
# 6     Happy     Happy

# %% [markdown]
# # Tablas de predicciones y clasificacion con Entrenamiento_pe1

# %% [markdown]
# ## Tabla de prediccion pe1

# %%
predict_pe1_pe1_table = pd.DataFrame(predict_pe1_pe1, columns = list(df_emotion["Emocion"]))

if "pe1_pe1" not in list(predict_pe1_pe1_table.columns.values):
  predict_pe1_pe1_table.insert(0,"pe1_pe1",emotion)
  predict_pe1_pe1_table.set_index("pe1_pe1",inplace = True)

predict_pe1_pe1_table
# Out:
#              Angry   Disgust      Fear     Happy   Neutral       Sad  Surprise
# pe1_pe1
# Disgust   0.000963  0.983521  0.000390  0.000086  0.000350  0.014335  0.000354
# Fear      0.100097  0.279834  0.348862  0.008762  0.036442  0.195282  0.030721
# Sad       0.288428  0.202351  0.011095  0.003761  0.022644  0.467944  0.003778
# Neutral   0.081910  0.151024  0.004624  0.019601  0.319453  0.412825  0.010563
# Surprise  0.000747  0.008490  0.064565  0.002199  0.004422  0.003606  0.915971
# Angry     0.493816  0.171749  0.007577  0.009759  0.035743  0.275220  0.006136
# Happy     0.003321  0.059259  0.010758  0.861700  0.031848  0.027662  0.005453

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe1

# %%
predict_y_pe1_pe1 = np.zeros((7,7))
predict_y_emotion_pe1_pe1 = [0]*7

for i in range(len(predict_pe1_pe1)):
  predict_y_pe1_pe1[i][np.argmax(predict_pe1_pe1[i])] = 1
  predict_y_emotion_pe1_pe1[i] = dic_y_emotion[np.argmax(predict_pe1_pe1[i])]

clasif_predict_pe1_pe1_table = pd.DataFrame(predict_y_pe1_pe1.astype(int), columns = list(df_emotion["Emocion"]))

if "pe1_pe1" not in list(clasif_predict_pe1_pe1_table.columns.values):
  clasif_predict_pe1_pe1_table.insert(0,"pe1_pe1",emotion)
  clasif_predict_pe1_pe1_table.set_index("pe1_pe1",inplace = True)

clasif_predict_pe1_pe1_table
# Out:
#           Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# pe1_pe1
# Disgust       0        1     0      0        0    0         0
# Fear          0        0     1      0        0    0         0
# Sad           0        0     0      0        0    1         0
# Neutral       0        0     0      0        0    1         0
# Surprise      0        0     0      0        0    0         1
# Angry         1        0     0      0        0    0         0
# Happy         0        0     0      1        0    0         0

# %%
predict_y_emotion_pe1_pe1_table = pd.DataFrame({'pe1_pe1':emotion,'Emotion':predict_y_emotion_pe1_pe1})
predict_y_emotion_pe1_pe1_table
# Out:
#     pe1_pe1   Emotion
# 0   Disgust   Disgust
# 1      Fear      Fear
# 2       Sad       Sad
# 3   Neutral       Sad
# 4  Surprise  Surprise
# 5     Angry     Angry
# 6     Happy     Happy

# %% [markdown]
# ## Tabla de prediccion pe2

# %%
predict_pe2_pe1_table = pd.DataFrame(predict_pe2_pe1, columns = list(df_emotion["Emocion"]))

if "pe2_pe1" not in list(predict_pe2_pe1_table.columns.values):
  predict_pe2_pe1_table.insert(0,"pe2_pe1",emotion)
  predict_pe2_pe1_table.set_index("pe2_pe1",inplace = True)

predict_pe2_pe1_table
# Out:
#                  Angry   Disgust      Fear     Happy   Neutral       Sad  \
# pe2_pe1
# Disgust   3.099377e-07  0.999800  0.000021  0.000018  0.000023  0.000078
# Fear      1.557875e-02  0.105674  0.828968  0.008699  0.010172  0.026080
# Sad       6.483302e-03  0.089997  0.004986  0.006056  0.004805  0.885812
# Neutral   3.424562e-01  0.028199  0.016548  0.023393  0.525335  0.056552
# Surprise  1.018372e-04  0.000701  0.002765  0.001042  0.001981  0.000572
# Angry     9.946223e-01  0.000979  0.000356  0.000579  0.001864  0.001449
# Happy     8.886831e-04  0.003895  0.003578  0.983448  0.001886  0.006034
#
#           Surprise
# pe2_pe1
# Disgust   0.000061
# Fear      0.004829
# Sad       0.001862
# Neutral   0.007517
# Surprise  0.992837
# Angry     0.000151
# Happy     0.000271

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe2

# %%
predict_y_pe2_pe1 = np.zeros((7,7))
predict_y_emotion_pe2_pe1 = [0]*7

for i in range(len(predict_pe2_pe1)):
  predict_y_pe2_pe1[i][np.argmax(predict_pe2_pe1[i])] = 1
  predict_y_emotion_pe2_pe1[i] = dic_y_emotion[np.argmax(predict_pe2_pe1[i])]

clasif_predict_pe2_pe1_table = pd.DataFrame(predict_y_pe2_pe1.astype(int), columns = list(df_emotion["Emocion"]))

if "pe2_pe1" not in list(clasif_predict_pe2_pe1_table.columns.values):
  clasif_predict_pe2_pe1_table.insert(0,"pe2_pe1",emotion)
  clasif_predict_pe2_pe1_table.set_index("pe2_pe1",inplace = True)

clasif_predict_pe2_pe1_table
# Out:
#           Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# pe2_pe1
# Disgust       0        1     0      0        0    0         0
# Fear          0        0     1      0        0    0         0
# Sad           0        0     0      0        0    1         0
# Neutral       0        0     0      0        1    0         0
# Surprise      0        0     0      0        0    0         1
# Angry         1        0     0      0        0    0         0
# Happy         0        0     0      1        0    0         0

# %%
predict_y_emotion_pe2_pe1_table = pd.DataFrame({'pe2_pe1':emotion,'Emotion':predict_y_emotion_pe2_pe1})
predict_y_emotion_pe2_pe1_table
# Out:
#     pe2_pe1   Emotion
# 0   Disgust   Disgust
# 1      Fear      Fear
# 2       Sad       Sad
# 3   Neutral   Neutral
# 4  Surprise  Surprise
# 5     Angry     Angry
# 6     Happy     Happy

# %% [markdown]
# # Tablas de predicciones y clasificacion con Entrenamiento_pe2

# %% [markdown]
# ## Tabla de prediccion pe1

# %%
predict_pe1_pe2_table = pd.DataFrame(predict_pe1_pe2, columns = list(df_emotion["Emocion"]))

if "pe1_pe2" not in list(predict_pe1_pe2_table.columns.values):
  predict_pe1_pe2_table.insert(0,"pe1_pe2",emotion)
  predict_pe1_pe2_table.set_index("pe1_pe2",inplace = True)

predict_pe1_pe2_table
# Out:
#              Angry   Disgust      Fear     Happy   Neutral       Sad  Surprise
# pe1_pe2
# Disgust   0.000279  0.978765  0.000284  0.000068  0.000225  0.020151  0.000228
# Fear      0.018520  0.109090  0.008112  0.002254  0.003722  0.857375  0.000927
# Sad       0.002887  0.068055  0.000656  0.000331  0.000499  0.927417  0.000155
# Neutral   0.010515  0.135873  0.003426  0.011744  0.328516  0.485394  0.024532
# Surprise  0.000134  0.015621  0.000244  0.000689  0.035114  0.004751  0.943447
# Angry     0.809924  0.043196  0.001303  0.001255  0.003121  0.140490  0.000711
# Happy     0.001512  0.004655  0.000343  0.991746  0.000213  0.000299  0.001234

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe1

# %%
predict_y_pe1_pe2 = np.zeros((7,7))
predict_y_emotion_pe1_pe2 = [0]*7

for i in range(len(predict_pe1_pe2)):
  predict_y_pe1_pe2[i][np.argmax(predict_pe1_pe2[i])] = 1
  predict_y_emotion_pe1_pe2[i] = dic_y_emotion[np.argmax(predict_pe1_pe2[i])]

clasif_predict_pe1_pe2_table = pd.DataFrame(predict_y_pe1_pe2.astype(int), columns = list(df_emotion["Emocion"]))

if "pe1_pe2" not in list(clasif_predict_pe1_pe2_table.columns.values):
  clasif_predict_pe1_pe2_table.insert(0,"pe1_pe2",emotion)
  clasif_predict_pe1_pe2_table.set_index("pe1_pe2",inplace = True)

clasif_predict_pe1_pe2_table
# Out:
#           Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# pe1_pe2
# Disgust       0        1     0      0        0    0         0
# Fear          0        0     0      0        0    1         0
# Sad           0        0     0      0        0    1         0
# Neutral       0        0     0      0        0    1         0
# Surprise      0        0     0      0        0    0         1
# Angry         1        0     0      0        0    0         0
# Happy         0        0     0      1        0    0         0

# %%
predict_y_emotion_pe1_pe2_table = pd.DataFrame({'pe1_pe2':emotion,'Emotion':predict_y_emotion_pe1_pe2})
predict_y_emotion_pe1_pe2_table
# Out:
#     pe1_pe2   Emotion
# 0   Disgust   Disgust
# 1      Fear       Sad
# 2       Sad       Sad
# 3   Neutral       Sad
# 4  Surprise  Surprise
# 5     Angry     Angry
# 6     Happy     Happy

# %% [markdown]
# ## Tabla de prediccion pe2

# %%
predict_pe2_pe2_table = pd.DataFrame(predict_pe2_pe2, columns = list(df_emotion["Emocion"]))

if "pe2_pe2" not in list(predict_pe2_pe2_table.columns.values):
  predict_pe2_pe2_table.insert(0,"pe2_pe2",emotion)
  predict_pe2_pe2_table.set_index("pe2_pe2",inplace = True)

predict_pe2_pe2_table
# Out:
#              Angry   Disgust      Fear     Happy   Neutral       Sad  Surprise
# pe2_pe2
# Disgust   0.000020  0.584802  0.000250  0.000020  0.000133  0.414716  0.000058
# Fear      0.000619  0.300874  0.044886  0.007131  0.006855  0.638496  0.001139
# Sad       0.000755  0.056227  0.011181  0.001593  0.003882  0.925751  0.000612
# Neutral   0.012710  0.103215  0.014607  0.067341  0.346668  0.417997  0.037461
# Surprise  0.000101  0.006222  0.001042  0.000529  0.003554  0.001227  0.987324
# Angry     0.012720  0.008075  0.002323  0.001295  0.001642  0.973576  0.000369
# Happy     0.005486  0.002062  0.022851  0.965593  0.000254  0.003417  0.000337

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe2

# %%
predict_y_pe2_pe2 = np.zeros((7,7))
predict_y_emotion_pe2_pe2 = [0]*7

for i in range(len(predict_pe2_pe2)):
  predict_y_pe2_pe2[i][np.argmax(predict_pe2_pe2[i])] = 1
  predict_y_emotion_pe2_pe2[i] = dic_y_emotion[np.argmax(predict_pe2_pe2[i])]

clasif_predict_pe2_pe2_table = pd.DataFrame(predict_y_pe2_pe2.astype(int), columns = list(df_emotion["Emocion"]))

if "pe2_pe2" not in list(clasif_predict_pe2_pe2_table.columns.values):
  clasif_predict_pe2_pe2_table.insert(0,"pe2_pe2",emotion)
  clasif_predict_pe2_pe2_table.set_index("pe2_pe2",inplace = True)

clasif_predict_pe2_pe2_table
# Out:
#           Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# pe2_pe2
# Disgust       0        1     0      0        0    0         0
# Fear          0        0     0      0        0    1         0
# Sad           0        0     0      0        0    1         0
# Neutral       0        0     0      0        0    1         0
# Surprise      0        0     0      0        0    0         1
# Angry         0        0     0      0        0    1         0
# Happy         0        0     0      1        0    0         0

# %%
predict_y_emotion_pe2_pe2_table = pd.DataFrame({'pe2_pe2':emotion,'Emotion':predict_y_emotion_pe2_pe2})
predict_y_emotion_pe2_pe2_table
# Out:
#     pe2_pe2   Emotion
# 0   Disgust   Disgust
# 1      Fear       Sad
# 2       Sad       Sad
# 3   Neutral       Sad
# 4  Surprise  Surprise
# 5     Angry       Sad
# 6     Happy     Happy

# %% [markdown]
# # Tablas de predicciones y clasificacion con Entrenamiento_pe12

# %% [markdown]
# ## Tabla de prediccion pe1

# %%
predict_pe1_pe12_table = pd.DataFrame(predict_pe1_pe12, columns = list(df_emotion["Emocion"]))

if "pe1_pe12" not in list(predict_pe1_pe12_table.columns.values):
  predict_pe1_pe12_table.insert(0,"pe1_pe12",emotion)
  predict_pe1_pe12_table.set_index("pe1_pe12",inplace = True)

predict_pe1_pe12_table
# Out:
#              Angry   Disgust      Fear     Happy   Neutral       Sad  Surprise
# pe1_pe12
# Disgust   0.151806  0.218657  0.092757  0.096598  0.144825  0.222001  0.073356
# Fear      0.171087  0.198728  0.099889  0.094907  0.131034  0.219802  0.084554
# Sad       0.188201  0.189071  0.094933  0.110143  0.144466  0.203521  0.069665
# Neutral   0.187175  0.217107  0.094918  0.101930  0.120911  0.204053  0.073906
# Surprise  0.143633  0.203623  0.107983  0.108342  0.141571  0.205574  0.089275
# Angry     0.189466  0.205534  0.089421  0.103703  0.119502  0.222291  0.070082
# Happy     0.157658  0.166810  0.139110  0.128406  0.112704  0.208991  0.086320

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe1

# %%
predict_y_pe1_pe12 = np.zeros((7,7))
predict_y_emotion_pe1_pe12 = [0]*7

for i in range(len(predict_pe1_pe12)):
  predict_y_pe1_pe12[i][np.argmax(predict_pe1_pe12[i])] = 1
  predict_y_emotion_pe1_pe12[i] = dic_y_emotion[np.argmax(predict_pe1_pe12[i])]

clasif_predict_pe1_pe12_table = pd.DataFrame(predict_y_pe1_pe12.astype(int), columns = list(df_emotion["Emocion"]))

if "pe1_pe12" not in list(clasif_predict_pe1_pe12_table.columns.values):
  clasif_predict_pe1_pe12_table.insert(0,"pe1_pe12",emotion)
  clasif_predict_pe1_pe12_table.set_index("pe1_pe12",inplace = True)

clasif_predict_pe1_pe12_table
# Out:
#           Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# pe1_pe12
# Disgust       0        0     0      0        0    1         0
# Fear          0        0     0      0        0    1         0
# Sad           0        0     0      0        0    1         0
# Neutral       0        1     0      0        0    0         0
# Surprise      0        0     0      0        0    1         0
# Angry         0        0     0      0        0    1         0
# Happy         0        0     0      0        0    1         0

# %%
predict_y_emotion_pe1_pe12_table = pd.DataFrame({'pe1_pe12':emotion,'Emotion':predict_y_emotion_pe1_pe12})
predict_y_emotion_pe1_pe12_table
# Out:
#    pe1_pe12  Emotion
# 0   Disgust      Sad
# 1      Fear      Sad
# 2       Sad      Sad
# 3   Neutral  Disgust
# 4  Surprise      Sad
# 5     Angry      Sad
# 6     Happy      Sad

# %% [markdown]
# ## Tabla de prediccion pe2

# %%
predict_pe2_pe12_table = pd.DataFrame(predict_pe2_pe12, columns = list(df_emotion["Emocion"]))

if "pe2_pe12" not in list(predict_pe2_pe12_table.columns.values):
  predict_pe2_pe12_table.insert(0,"pe2_pe12",emotion)
  predict_pe2_pe12_table.set_index("pe2_pe12",inplace = True)

predict_pe2_pe12_table
# Out:
#              Angry   Disgust      Fear     Happy   Neutral       Sad  Surprise
# pe2_pe12
# Disgust   0.180439  0.226235  0.090504  0.099842  0.134490  0.205709  0.062781
# Fear      0.173971  0.239491  0.099815  0.087988  0.096563  0.224188  0.077985
# Sad       0.172362  0.221097  0.095809  0.108571  0.137437  0.192038  0.072687
# Neutral   0.199109  0.238186  0.081701  0.087620  0.116354  0.211111  0.065920
# Surprise  0.186466  0.247098  0.097954  0.085303  0.099995  0.208736  0.074448
# Angry     0.186713  0.228082  0.093517  0.098253  0.129420  0.200841  0.063175
# Happy     0.164769  0.221666  0.094459  0.102588  0.136616  0.210404  0.069496

# %% [markdown]
# ## Tabla de clasificacion de prediccion pe2

# %%
predict_y_pe2_pe12 = np.zeros((7,7))
predict_y_emotion_pe2_pe12 = [0]*7

for i in range(len(predict_pe2_pe12)):
  predict_y_pe2_pe12[i][np.argmax(predict_pe2_pe12[i])] = 1
  predict_y_emotion_pe2_pe12[i] = dic_y_emotion[np.argmax(predict_pe2_pe12[i])]

clasif_predict_pe2_pe12_table = pd.DataFrame(predict_y_pe2_pe12.astype(int), columns = list(df_emotion["Emocion"]))

if "pe2_pe12" not in list(clasif_predict_pe2_pe12_table.columns.values):
  clasif_predict_pe2_pe12_table.insert(0,"pe2_pe12",emotion)
  clasif_predict_pe2_pe12_table.set_index("pe2_pe12",inplace = True)

clasif_predict_pe2_pe12_table
# Out:
#           Angry  Disgust  Fear  Happy  Neutral  Sad  Surprise
# pe2_pe12
# Disgust       0        1     0      0        0    0         0
# Fear          0        1     0      0        0    0         0
# Sad           0        1     0      0        0    0         0
# Neutral       0        1     0      0        0    0         0
# Surprise      0        1     0      0        0    0         0
# Angry         0        1     0      0        0    0         0
# Happy         0        1     0      0        0    0         0

# %%
predict_y_emotion_pe2_pe12_table = pd.DataFrame({'pe2_pe12':emotion,'Emotion':predict_y_emotion_pe2_pe12})
predict_y_emotion_pe2_pe12_table
# Out:
#    pe2_pe12  Emotion
# 0   Disgust  Disgust
# 1      Fear  Disgust
# 2       Sad  Disgust
# 3   Neutral  Disgust
# 4  Surprise  Disgust
# 5     Angry  Disgust
# 6     Happy  Disgust
